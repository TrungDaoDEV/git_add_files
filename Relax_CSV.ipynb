# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Relax.csv", sep=';')

# %%
df.head(5)
# Out:
#       Ngày PS-Open PS-High PS-Low PS-Close CS-Open CS-High CS-Low CS-Close  \
# 0  15-Thg7     NaN     NaN    NaN      NaN     NaN     NaN    NaN      NaN
# 1  14-Thg7     NaN     NaN    NaN      NaN     NaN     NaN    NaN      NaN
# 2  13-Thg7     NaN     NaN    NaN      NaN     NaN     NaN    NaN      NaN
# 3  12-Thg7     NaN     NaN    NaN      NaN     NaN     NaN    NaN      NaN
# 4  11-Thg7     NaN     NaN    NaN      NaN     NaN     NaN    NaN      NaN
#
#   KL_PS(K) KL_CS(M) K?t qu? Trade (Giá) PS H-L CS H-L CS C-O CS - PS   \
# 0      NaN      NaN                 NaN      0      0      0        0
# 1      NaN      NaN                 NaN      0      0      0        0
# 2      NaN      NaN                 NaN      0      0      0        0
# 3      NaN      NaN                 NaN      0      0      0        0
# 4      NaN      NaN                 NaN      0      0      0        0
#
#   CS(C)-PS(C)
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
df.dtypes
# Out:
# Ngày                   object
# PS-Open                object
# PS-High                object
# PS-Low                 object
# PS-Close               object
# CS-Open                object
# CS-High                object
# CS-Low                 object
# CS-Close               object
# KL_PS(K)               object
# KL_CS(M)               object
# K?t qu? Trade (Giá)    object
# PS H-L                 object
# CS H-L                 object
# CS C-O                 object
# CS - PS                object
# CS(C)-PS(C)            object
# dtype: object

# %%
df.tail()
# Out:
#        Ngày PS-Open PS-High PS-Low PS-Close  CS-Open  CS-High   CS-Low  \
# 63  15-Thg4     NaN     NaN    NaN      NaN  1514,89  1518,85  1491,26
# 64  14-Thg4     NaN     NaN    NaN      NaN  1526,49  1534,28  1517,07
# 65  13-Thg4     NaN     NaN    NaN      NaN  1512,37  1526,44  1506,45
# 66  12-Thg4     NaN     NaN    NaN      NaN   1530,3  1532,03  1506,41
# 67  08-Thg4     NaN     NaN    NaN      NaN  1541,78   1547,6  1524,31
#
#    CS-Close KL_PS(K) KL_CS(M) K?t qu? Trade (Giá) PS H-L CS H-L  CS C-O  \
# 63  1493,74      NaN  181,765                 NaN      0  27,59  -21,15
# 64  1518,01      NaN  119,609                 NaN      0  17,21   -8,48
# 65  1525,39      NaN  143,872                 NaN      0  19,99   13,02
# 66   1507,2      NaN  152,482                 NaN      0  25,62   -23,1
# 67  1524,31      NaN  156,336                 NaN      0  23,29  -17,47
#
#    CS - PS  CS(C)-PS(C)
# 63      NaN         NaN
# 64      NaN         NaN
# 65      NaN         NaN
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=68, step=1)

# %%
df.columns
# Out:
# Index(['Ngày', 'PS-Open', 'PS-High', 'PS-Low', 'PS-Close', 'CS-Open',
#        'CS-High', 'CS-Low', 'CS-Close', 'KL_PS(K)', 'KL_CS(M)',
#        'K?t qu? Trade (Giá)', 'PS H-L', 'CS H-L', 'CS C-O', 'CS - PS ',
#        'CS(C)-PS(C)'],
#       dtype='object')

# %%
df.to_numpy()
# Out:
# array([['15-Thg7', nan, nan, ..., '0', '0', '0'],
#        ['14-Thg7', nan, nan, ..., '0', '0', '0'],
#        ['13-Thg7', nan, nan, ..., '0', '0', '0'],
#        ...,
#        ['13-Thg4', nan, nan, ..., '13,02', nan, nan],
#        ['12-Thg4', nan, nan, ..., '-23,1', nan, nan],
#        ['08-Thg4', nan, nan, ..., '-17,47', nan, nan]], dtype=object)

# %%
df.describe()
# Out:
#            Ngày PS-Open PS-High PS-Low PS-Close  CS-Open  CS-High   CS-Low  \
# count        68      53      53     53       53       62       62       62
# unique       68      50      53     49       48       62       62       62
# top     15-Thg7    1275  1226,2   1234     1315  1212,36  1229,23  1209,97
# freq          1       2       1      3        3        1        1        1
#
#        CS-Close KL_PS(K) KL_CS(M) K?t qu? Trade (Giá) PS H-L CS H-L CS C-O  \
# count        62       35       62                  31     68     68     68
# unique       62       35       62                  24     50     63     63
# top     1229,23  319,336   98,639                   0      0      0      0
# freq          1        1        1                   5     15      6      6
#
#        CS - PS  CS(C)-PS(C)
# count        59          59
# unique       53          53
# top           0           0
# freq          6           6

# %%
df.T
# Out:
#                           0        1        2        3        4        5   \
# Ngày                 15-Thg7  14-Thg7  13-Thg7  12-Thg7  11-Thg7  08-Thg7
# PS-Open                  NaN      NaN      NaN      NaN      NaN      NaN
# PS-High                  NaN      NaN      NaN      NaN      NaN      NaN
# PS-Low                   NaN      NaN      NaN      NaN      NaN      NaN
# PS-Close                 NaN      NaN      NaN      NaN      NaN      NaN
# CS-Open                  NaN      NaN      NaN      NaN      NaN      NaN
# CS-High                  NaN      NaN      NaN      NaN      NaN      NaN
# CS-Low                   NaN      NaN      NaN      NaN      NaN      NaN
# CS-Close                 NaN      NaN      NaN      NaN      NaN      NaN
# KL_PS(K)                 NaN      NaN      NaN      NaN      NaN      NaN
# KL_CS(M)                 NaN      NaN      NaN      NaN      NaN      NaN
# K?t qu? Trade (Giá)      NaN      NaN      NaN      NaN      NaN      NaN
# ...

# %%
df = df.sort_values(by="Ngày")

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#    PS-Open PS-Low PS-High PS-Close PS H-L     Ngày KL_PS(K) KL_CS(M)  \
# 0      NaN    NaN     NaN      NaN      0  15-Thg7      NaN      NaN
# 1      NaN    NaN     NaN      NaN      0  14-Thg7      NaN      NaN
# 2      NaN    NaN     NaN      NaN      0  13-Thg7      NaN      NaN
# 3      NaN    NaN     NaN      NaN      0  12-Thg7      NaN      NaN
# 4      NaN    NaN     NaN      NaN      0  11-Thg7      NaN      NaN
# ..     ...    ...     ...      ...    ...      ...      ...      ...
# 63     NaN    NaN     NaN      NaN      0  15-Thg4      NaN  181,765
# 64     NaN    NaN     NaN      NaN      0  14-Thg4      NaN  119,609
# 65     NaN    NaN     NaN      NaN      0  13-Thg4      NaN  143,872
# 66     NaN    NaN     NaN      NaN      0  12-Thg4      NaN  152,482
# 67     NaN    NaN     NaN      NaN      0  08-Thg4      NaN  156,336
#
#    K?t qu? Trade (Giá)  CS-Open   CS-Low  CS-High CS-Close CS(C)-PS(C) CS H-L  \
# ...

# %%
df.head(15)
# Out:
#        Ngày PS-Open PS-High  PS-Low PS-Close  CS-Open  CS-High   CS-Low  \
# 32  01-Thg6  1318,5  1337,5    1316     1326  1329,02  1341,47  1323,07
# 10  01-Thg7    1241  1243,5  1221,5     1242   1247,7  1255,67  1225,64
# 31  02-Thg6    1311    1330    1311     1315  1339,12  1342,47  1319,85
# 30  03-Thg6    1318  1323,9  1305,6   1318,5  1323,09   1329,9   1313,4
# 52  04-Thg5  1408,3  1409,9    1383     1383  1415,43  1415,45  1389,59
# 9   04-Thg7    1247  1252,1  1238,1     1242   1256,2  1260,72   1244,5
# 51  05-Thg5    1392  1403,6  1372,6   1402,5   1402,6  1405,43  1373,42
# 8   05-Thg7  1248,3  1251,9    1234   1234,9  1252,48  1256,47   1239,8
# 50  06-Thg5    1382  1396,3  1358,8     1362  1399,54  1399,54     1371
# 29  06-Thg6  1320,7    1332    1315     1315  1328,73  1336,96  1320,97
# 7   06-Thg7  1234,8  1234,8  1213,4     1218  1241,19  1241,19  1211,94
# 28  07-Thg6    1315  1315,5  1293,3     1315  1323,19  1324,27  1297,98
# ...
