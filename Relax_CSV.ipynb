# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ps.csv", sep=';')

# %%
df.head(5)
# Out:
#    Trading order      Time     Price  +/- Volumn Lease
# 0           4722  14:45:10     1.225    7  6,684     B
# 1           4721  14:30:05  1.223,80  5,8   0,06     S
# 2           4720  14:30:01  1.223,20  5,2  0,163     B
# 3           4719  14:29:57  1.223,80  5,8  0,133     S
# 4           4718  14:29:52  1.223,20  5,2  0,129     B

# %%
df.dtypes
# Out:
# Trading order     int64
# Time             object
# Price            object
# +/-              object
# Volumn           object
# Lease            object
# dtype: object

# %%
df.tail()
# Out:
#       Trading order     Time     Price   +/- Volumn Lease
# 4717              5  9:00:32  1.215,50  -2,5  0,152     S
# 4718              4  9:00:30  1.214,70  -3,3  0,044     B
# 4719              3  9:00:25     1.215    -3  0,026     B
# 4720              2  9:00:18  1.215,20  -2,8  0,004     B
# 4721              1  9:00:11  1.215,30  -2,7  1,978     B

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4722, step=1)

# %%
df.columns
# Out:
# Index(['Trading order', 'Time', 'Price', '+/-', 'Volumn', 'Lease'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[4722, '14:45:10', '1.225', '7', '6,684', 'B'],
#        [4721, '14:30:05', '1.223,80', '5,8', '0,06', 'S'],
#        [4720, '14:30:01', '1.223,20', '5,2', '0,163', 'B'],
#        ...,
#        [3, '9:00:25', '1.215', '-3', '0,026', 'B'],
#        [2, '9:00:18', '1.215,20', '-2,8', '0,004', 'B'],
#        [1, '9:00:11', '1.215,30', '-2,7', '1,978', 'B']], dtype=object)

# %%
df.describe()
# Out:
#        Trading order
# count    4722.000000
# mean     2361.500000
# std      1363.268315
# min         1.000000
# 25%      1181.250000
# 50%      2361.500000
# 75%      3541.750000
# max      4722.000000

# %%
df.T
# Out:
#                    0         1         2         3         4         5     \
# Trading order      4722      4721      4720      4719      4718      4717
# Time           14:45:10  14:30:05  14:30:01  14:29:57  14:29:52  14:29:48
# Price             1.225  1.223,80  1.223,20  1.223,80  1.223,20  1.223,40
# +/-                   7       5,8       5,2       5,8       5,2       5,4
# Volumn            6,684      0,06     0,163     0,133     0,129     0,098
# Lease                 B         S         B         S         B         S
#
#                    6         7         8         9     ...      4712  \
# Trading order      4716      4715      4714      4713  ...        10
# Time           14:29:44  14:29:40  14:29:36  14:29:32  ...   9:00:41
# Price          1.222,90  1.222,60  1.222,90  1.222,60  ...  1.215,30
# +/-                 4,9       4,6       4,9       4,6  ...      -2,7
# Volumn            0,287     0,182     0,222     0,146  ...     0,005
# ...

# %%
df = df.sort_values(by="Ngày")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 df = df.sort_values(by="Ngày")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6313, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6309 elif len(by):
#    6310     # len(by) == 1
#    6312     by = by[0]
# -> 6313     k = self._get_label_or_level_values(by, axis=axis)
# ...

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#    PS-Open PS-Low PS-High PS-Close PS H-L     Ngày KL_PS(K) KL_CS(M)  \
# 0      NaN    NaN     NaN      NaN      0  15-Thg7      NaN      NaN
# 1      NaN    NaN     NaN      NaN      0  14-Thg7      NaN      NaN
# 2      NaN    NaN     NaN      NaN      0  13-Thg7      NaN      NaN
# 3      NaN    NaN     NaN      NaN      0  12-Thg7      NaN      NaN
# 4      NaN    NaN     NaN      NaN      0  11-Thg7      NaN      NaN
# ..     ...    ...     ...      ...    ...      ...      ...      ...
# 63     NaN    NaN     NaN      NaN      0  15-Thg4      NaN  181,765
# 64     NaN    NaN     NaN      NaN      0  14-Thg4      NaN  119,609
# 65     NaN    NaN     NaN      NaN      0  13-Thg4      NaN  143,872
# 66     NaN    NaN     NaN      NaN      0  12-Thg4      NaN  152,482
# 67     NaN    NaN     NaN      NaN      0  08-Thg4      NaN  156,336
#
#    K?t qu? Trade (Giá)  CS-Open   CS-Low  CS-High CS-Close CS(C)-PS(C) CS H-L  \
# ...

# %%
df.head(15)
# Out:
#        Ngày PS-Open PS-High  PS-Low PS-Close  CS-Open  CS-High   CS-Low  \
# 32  01-Thg6  1318,5  1337,5    1316     1326  1329,02  1341,47  1323,07
# 10  01-Thg7    1241  1243,5  1221,5     1242   1247,7  1255,67  1225,64
# 31  02-Thg6    1311    1330    1311     1315  1339,12  1342,47  1319,85
# 30  03-Thg6    1318  1323,9  1305,6   1318,5  1323,09   1329,9   1313,4
# 52  04-Thg5  1408,3  1409,9    1383     1383  1415,43  1415,45  1389,59
# 9   04-Thg7    1247  1252,1  1238,1     1242   1256,2  1260,72   1244,5
# 51  05-Thg5    1392  1403,6  1372,6   1402,5   1402,6  1405,43  1373,42
# 8   05-Thg7  1248,3  1251,9    1234   1234,9  1252,48  1256,47   1239,8
# 50  06-Thg5    1382  1396,3  1358,8     1362  1399,54  1399,54     1371
# 29  06-Thg6  1320,7    1332    1315     1315  1328,73  1336,96  1320,97
# 7   06-Thg7  1234,8  1234,8  1213,4     1218  1241,19  1241,19  1211,94
# 28  07-Thg6    1315  1315,5  1293,3     1315  1323,19  1324,27  1297,98
# ...
